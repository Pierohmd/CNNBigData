# %%
import csv
import pandas as pd

# %% [markdown]
# Visualizzazione del dataset

# %%
quadro1 = pd.read_csv("Quadro1.csv",delimiter=',',header=None,
                    names=['prov1','prov2','Frecciarossa al giorno'])
quadro2 = pd.read_csv("Quadro2.csv",delimiter=',',header=None,
                    names=['prov1','prov2','Frecciarossa al giorno'])
quadro3 = pd.read_csv("Quadro3.csv",delimiter=',',header=None,
                    names=['prov1','prov2','Frecciarossa al giorno'])
quadro5 = pd.read_csv("Quadro5.csv",delimiter=',',header=None,
                    names=['prov1','prov2','Frecciarossa al giorno'])

# %%
quadro1 #visualizzazione quadro1,quadro2,quadro3,quadro5.
# Out:
#       prov1          prov2  Frecciarossa al giorno
# 0   Brescia         Torino                       0
# 1   Brescia         Milano                       2
# 2   Brescia       Piacenza                       0
# 3   Brescia          Parma                       0
# 4   Brescia  Reggio Emilia                       0
# ..      ...            ...                     ...
# 73  Perugia         Napoli                       0
# 74  Perugia        Salerno                       0
# 75   Napoli        Salerno                      24
# 76     Roma         Napoli                      92
# 77     Roma        Salerno                      24
#
# [78 rows x 3 columns]

# %% [markdown]
# Inserisco info del dataset in liste

# %%
quadro1=[]
quadro2=[]
quadro3=[]
quadro5=[]

with open ("Quadro1.csv") as file:     
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        quadro1.append(line)
with open ("Quadro2.csv") as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        quadro2.append(line)
with open ("Quadro3.csv") as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        quadro3.append(line)
with open ("Quadro5.csv") as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        quadro5.append(line)

# %% [markdown]
# ### dataset comuni

# %%
#visualizzazione con pandas
comuni = pd.read_csv("GeolocComuni.csv",delimiter=',')
comuni
# Out:
#       id_istat           comune       lng        lat   regione
# 0         1001            Agliè  7.768600  45.363433  Piemonte
# 1         1002          Airasca  7.484431  44.916886  Piemonte
# 2         1003     Ala di Stura  7.304344  45.315110  Piemonte
# 3         1004  Albiano d'Ivrea  7.949145  45.433893  Piemonte
# 4         1006           Almese  7.395182  45.117663  Piemonte
# ...        ...              ...       ...        ...       ...
# 7899    111103       Villaputzu  9.574832  39.440086  Sardegna
# 7900    111104       Villasalto  9.388774  39.493758  Sardegna
# 7901    111105      Villasimius  9.520365  39.142384  Sardegna
# 7902    111106         Villasor  8.940650  39.380689  Sardegna
# 7903    111107    Villaspeciosa  8.926934  39.312805  Sardegna
#
# [7904 rows x 5 columns]

# %%
comuni = []
# 0 id_istat
# 1 nome comune
# 2 long
# 3 lat
# 4 regione
with open ("GeolocComuni.csv") as file:     ############## da completare
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        comuni.append(line)

# %% [markdown]
# ### converto i numeri nei quadri in interi e sostituisco eventuali spazi vuoti con zeri

# %%
for quadro in [quadro1,quadro2,quadro3,quadro5]:
    for riga in quadro:
        if riga[2]=='' or riga[2]==' ':
            riga[2] = int(0)  ## converte i vuoti in zeri
        else:
            riga[2] = int(riga[2])
        if riga[1][0] == ' ': ## toglie gli spazi prima del nome delle città
            riga[1] = riga[1][1:]
        if riga[1] == 'Reggio Emilia': ## cambio nome reggio emilia per compatibilitá
            riga[1] = "Reggio nell'Emilia"
        if riga[0] == 'Reggio Emilia':
            riga[0] = "Reggio nell'Emilia"
            
### Check
for quadro in [quadro1,quadro2,quadro3,quadro5]:
    for riga in quadro:
        if type(riga[0]) != type(''): # controlla se al posto 0 di ogni riga c'è una stringa
            print('Problema: ', riga)
        elif type(riga[1]) != type(''): # controlla se al posto 1 di ogni riga c'è una stringa
            print('Problema: ', riga)
        elif type(riga[2]) != type(int(0)): # controlla se al posto 2 di ogni riga c'è un intero
            print('Problema: ', riga)
        elif riga[1][0] == ' ': # controlla se al posto 1 di ogni riga, la stringa non inizia con uno spazio
            print('Problema spazio', riga)
        elif len(riga) != 3: # controlla che la lunghezza di ogni riga sia 3
            print('Problema Lunghezza : ', riga)
        elif riga[0][0] == ' ': # controlla se al posto 0 di ogni riga, la stringa non inizia con uno spazio
            print('Problema spazio : ', riga)

# %% [markdown]
# ## Unisco prima tutti i quadri e poi cerco i "doppioni" e li sommo. Inoltre rimuove le righe con zero collegamenti

# %%
def somma_su_doppioni(quadri):
    quadri_new = []
    lista_tratte = []
    for riga in quadri:
        if (riga[0]+riga[1] in lista_tratte) or (riga[1]+riga[0] in lista_tratte):
            try: index = lista_tratte.index(riga[0]+riga[1])
            except: index = lista_tratte.index(riga[1]+riga[0])
            quadri_new[index][2] += riga[2]
        else:
            quadri_new.append(riga)
            lista_tratte = [rigaa[0]+rigaa[1] for rigaa in quadri_new]
    
    return quadri_new
quadri = quadro1+quadro2+quadro3+quadro5

# elimino righe con zero collegamenti
indici_da_eliminare = []
for ii, riga in enumerate(quadri):
    if riga[2]==0:
        indici_da_eliminare.append(ii)

for indice in indici_da_eliminare[::-1]: # vado all'indietro altrimenti gli indici si modificano
    quadri.pop(indice)

# sommo sui doppioni
quadri_new = somma_su_doppioni(quadri)

# %% [markdown]
# ### Innanzitutto controllo che ci siano solo "andate". Poi creo i ritorni e divido tutti i numeri di treni per due, approssimando per difetto quando serve.

# %%
## controllo che ogni tratta compaia solo in una direzione, e non anche inversa.
lista_tratte = lista_tratte = [rigaa[0]+rigaa[1] for rigaa in quadri_new]
for riga in quadri_new:
    if riga[0]+riga[1] in lista_tratte:
        if riga[1]+riga[0] in lista_tratte:
            print('problema')
    elif riga[1]+riga[0] in lista_tratte:
        if riga[0]+riga[1] in lista_tratte:
            print('problema')
    else:
        print('problema !')

# %%
## aggiungo anche le tratte inverse
quadri_temp = []
for riga in quadri_new:
    quadri_temp.append([riga[1],riga[0],riga[2]])
quadri_new += quadri_temp

for riga in quadri_new:
    riga[2] = riga[2]//2
    
quadri_new = sorted(sorted(quadri_new,key=lambda x: x[1]), key=lambda x: x[0])
quadri_new
# Out:
# [['Ancona', 'Bari', 4],
#  ['Ancona', 'Barletta', 3],
#  ['Ancona', 'Bologna', 5],
#  ['Ancona', 'Brindisi', 2],
#  ['Ancona', 'Foggia', 4],
#  ['Ancona', 'Forlì', 1],
#  ['Ancona', 'Lecce', 2],
#  ['Ancona', 'Milano', 5],
#  ['Ancona', 'Pesaro', 3],
#  ['Ancona', 'Pescara', 5],
#  ['Ancona', "Reggio nell'Emilia", 5],
#  ['Ancona', 'Riccione', 2],
#  ['Ancona', 'Rimini', 5],
#  ['Ancona', 'Termoli', 4],
#  ['Ancona', 'Torino', 3],
#  ['Bari', 'Ancona', 4],
#  ['Bari', 'Barletta', 3],
#  ['Bari', 'Bologna', 4],
#  ['Bari', 'Brindisi', 2],
#  ['Bari', 'Foggia', 4],
#  ['Bari', 'Lecce', 2],
#  ['Bari', 'Milano', 4],
#  ['Bari', 'Pesaro', 3],
#  ['Bari', 'Pescara', 4],
#  ['Bari', "Reggio nell'Emilia", 4],
#  ['Bari', 'Riccione', 2],
#  ['Bari', 'Rimini', 4],
#  ['Bari', 'Termoli', 4],
#  ['Bari', 'Torino', 3],
#  ['Barletta', 'Ancona', 3],
#  ['Barletta', 'Bari', 3],
#  ['Barletta', 'Bologna', 3],
#  ['Barletta', 'Brindisi', 2],
#  ['Barletta', 'Foggia', 3],
#  ['Barletta', 'Lecce', 2],
#  ['Barletta', 'Milano', 3],
#  ['Barletta', 'Pesaro', 3],
#  ['Barletta', 'Pescara', 3],
#  ['Barletta', "Reggio nell'Emilia", 3],
#  ['Barletta', 'Riccione', 2],
#  ['Barletta', 'Rimini', 3],
#  ['Barletta', 'Termoli', 3],
#  ['Barletta', 'Torino', 3],
#  ['Bergamo', 'Bologna', 1],
#  ['Bergamo', 'Brescia', 1],
#  ['Bergamo', 'Firenze', 1],
#  ['Bergamo', 'Roma', 1],
#  ['Bergamo', 'Verona', 1],
#  ['Bologna', 'Ancona', 5],
#  ['Bologna', 'Bari', 4],
#  ['Bologna', 'Barletta', 3],
#  ['Bologna', 'Bergamo', 1],
#  ['Bologna', 'Bolzano', 1],
#  ['Bologna', 'Brescia', 2],
#  ['Bologna', 'Brindisi', 2],
#  ['Bologna', 'Ferrara', 18],
#  ['Bologna', 'Firenze', 51],
#  ['Bologna', 'Foggia', 4],
#  ['Bologna', 'Forlì', 1],
#  ['Bologna', 'Lecce', 2],
#  ['Bologna', 'Milano', 60],
#  ['Bologna', 'Modena', 1],
#  ['Bologna', 'Napoli', 45],
#  ['Bologna', 'Padova', 18],
#  ['Bologna', 'Parma', 1],
#  ['Bologna', 'Perugia', 1],
#  ['Bologna', 'Pesaro', 4],
#  ['Bologna', 'Pescara', 5],
#  ['Bologna', 'Piacenza', 1],
#  ['Bologna', "Reggio nell'Emilia", 44],
#  ['Bologna', 'Riccione', 2],
#  ['Bologna', 'Rimini', 5],
#  ['Bologna', 'Roma', 67],
#  ['Bologna', 'Rovigo', 4],
#  ['Bologna', 'Salerno', 11],
#  ['Bologna', 'Termoli', 4],
#  ['Bologna', 'Torino', 18],
#  ['Bologna', 'Trento', 1],
#  ['Bologna', 'Treviso', 2],
#  ['Bologna', 'Udine', 2],
#  ['Bologna', 'Venezia', 18],
#  ['Bologna', 'Verona', 2],
#  ['Bolzano', 'Bologna', 1],
#  ['Bolzano', 'Brescia', 1],
#  ['Bolzano', 'Firenze', 1],
#  ['Bolzano', 'Milano', 1],
#  ['Bolzano', 'Roma', 1],
#  ['Bolzano', 'Trento', 2],
#  ['Bolzano', 'Verona', 2],
#  ['Brescia', 'Bergamo', 1],
#  ['Brescia', 'Bologna', 2],
#  ['Brescia', 'Bolzano', 1],
#  ['Brescia', 'Firenze', 1],
#  ['Brescia', 'Genova', 1],
#  ['Brescia', 'Milano', 33],
#  ['Brescia', 'Napoli', 1],
#  ['Brescia', 'Padova', 25],
#  ['Brescia', 'Pavia', 1],
#  ['Brescia', 'Roma', 2],
#  ['Brescia', 'Torino', 2],
#  ['Brescia', 'Trento', 1],
#  ['Brescia', 'Treviso', 1],
#  ['Brescia', 'Trieste', 4],
#  ['Brescia', 'Udine', 1],
#  ['Brescia', 'Venezia', 30],
#  ['Brescia', 'Verona', 32],
#  ['Brescia', 'Vicenza', 25],
#  ['Brindisi', 'Ancona', 2],
#  ['Brindisi', 'Bari', 2],
#  ['Brindisi', 'Barletta', 2],
#  ['Brindisi', 'Bologna', 2],
#  ['Brindisi', 'Foggia', 2],
#  ['Brindisi', 'Lecce', 2],
#  ['Brindisi', 'Milano', 2],
#  ['Brindisi', 'Pesaro', 2],
#  ['Brindisi', 'Pescara', 2],
#  ['Brindisi', "Reggio nell'Emilia", 2],
#  ['Brindisi', 'Riccione', 2],
#  ['Brindisi', 'Rimini', 3],
#  ['Brindisi', 'Termoli', 2],
#  ['Brindisi', 'Torino', 2],
#  ['Ferrara', 'Bologna', 18],
#  ['Ferrara', 'Firenze', 12],
#  ['Ferrara', 'Napoli', 7],
#  ['Ferrara', 'Padova', 13],
#  ['Ferrara', 'Roma', 12],
#  ['Ferrara', 'Salerno', 1],
#  ['Ferrara', 'Treviso', 2],
#  ['Ferrara', 'Udine', 2],
#  ['Ferrara', 'Venezia', 13],
#  ['Firenze', 'Bergamo', 1],
#  ['Firenze', 'Bologna', 51],
#  ['Firenze', 'Bolzano', 1],
#  ['Firenze', 'Brescia', 1],
#  ['Firenze', 'Ferrara', 12],
#  ['Firenze', 'Milano', 34],
#  ['Firenze', 'Modena', 1],
#  ['Firenze', 'Napoli', 40],
#  ['Firenze', 'Padova', 16],
#  ['Firenze', 'Parma', 1],
#  ['Firenze', 'Perugia', 1],
#  ['Firenze', 'Piacenza', 1],
#  ['Firenze', "Reggio nell'Emilia", 34],
#  ['Firenze', 'Roma', 51],
#  ['Firenze', 'Rovigo', 4],
#  ['Firenze', 'Salerno', 11],
#  ['Firenze', 'Torino', 12],
#  ['Firenze', 'Trento', 1],
#  ['Firenze', 'Treviso', 2],
#  ['Firenze', 'Udine', 2],
#  ['Firenze', 'Venezia', 16],
#  ['Firenze', 'Verona', 2],
#  ['Foggia', 'Ancona', 4],
#  ['Foggia', 'Bari', 4],
#  ['Foggia', 'Barletta', 3],
#  ['Foggia', 'Bologna', 4],
#  ['Foggia', 'Brindisi', 2],
#  ['Foggia', 'Lecce', 2],
#  ['Foggia', 'Milano', 4],
#  ['Foggia', 'Pesaro', 3],
#  ['Foggia', 'Pescara', 4],
#  ['Foggia', "Reggio nell'Emilia", 4],
#  ['Foggia', 'Riccione', 2],
#  ['Foggia', 'Rimini', 4],
#  ['Foggia', 'Termoli', 4],
#  ['Foggia', 'Torino', 3],
#  ['Forlì', 'Ancona', 1],
#  ['Forlì', 'Bologna', 1],
#  ['Forlì', 'Milano', 1],
#  ['Forlì', 'Pesaro', 1],
#  ['Forlì', 'Pescara', 1],
#  ['Forlì', "Reggio nell'Emilia", 1],
#  ['Forlì', 'Rimini', 1],
#  ['Genova', 'Brescia', 1],
#  ['Genova', 'Milano', 1],
#  ['Genova', 'Padova', 1],
#  ['Genova', 'Pavia', 1],
#  ['Genova', 'Venezia', 1],
#  ['Genova', 'Verona', 1],
#  ['Genova', 'Vicenza', 1],
#  ['Lecce', 'Ancona', 2],
#  ['Lecce', 'Bari', 2],
#  ['Lecce', 'Barletta', 2],
#  ['Lecce', 'Bologna', 2],
#  ['Lecce', 'Brindisi', 2],
#  ['Lecce', 'Foggia', 2],
#  ['Lecce', 'Milano', 2],
#  ['Lecce', 'Pesaro', 2],
#  ['Lecce', 'Pescara', 2],
#  ['Lecce', "Reggio nell'Emilia", 2],
#  ['Lecce', 'Riccione', 2],
#  ['Lecce', 'Rimini', 3],
#  ['Lecce', 'Termoli', 2],
#  ['Lecce', 'Torino', 2],
#  ['Milano', 'Ancona', 5],
#  ['Milano', 'Bari', 4],
#  ['Milano', 'Barletta', 3],
#  ['Milano', 'Bologna', 60],
#  ['Milano', 'Bolzano', 1],
#  ['Milano', 'Brescia', 33],
#  ['Milano', 'Brindisi', 2],
#  ['Milano', 'Firenze', 34],
#  ['Milano', 'Foggia', 4],
#  ['Milano', 'Forlì', 1],
#  ['Milano', 'Genova', 1],
#  ['Milano', 'Lecce', 2],
#  ['Milano', 'Modena', 1],
#  ['Milano', 'Napoli', 45],
#  ['Milano', 'Padova', 25],
#  ['Milano', 'Parma', 1],
#  ['Milano', 'Pavia', 1],
#  ['Milano', 'Perugia', 1],
#  ['Milano', 'Pesaro', 4],
#  ['Milano', 'Pescara', 5],
#  ['Milano', 'Piacenza', 1],
#  ['Milano', "Reggio nell'Emilia", 44],
#  ['Milano', 'Riccione', 2],
#  ['Milano', 'Rimini', 5],
#  ['Milano', 'Roma', 65],
#  ['Milano', 'Salerno', 12],
#  ['Milano', 'Termoli', 4],
#  ['Milano', 'Torino', 80],
#  ['Milano', 'Trento', 1],
#  ['Milano', 'Treviso', 1],
#  ['Milano', 'Trieste', 4],
#  ['Milano', 'Udine', 1],
#  ['Milano', 'Venezia', 25],
#  ['Milano', 'Verona', 32],
#  ['Milano', 'Vicenza', 25],
#  ['Modena', 'Bologna', 1],
#  ['Modena', 'Firenze', 1],
#  ['Modena', 'Milano', 1],
#  ['Modena', 'Parma', 1],
#  ['Modena', 'Piacenza', 1],
#  ['Modena', "Reggio nell'Emilia", 1],
#  ['Modena', 'Roma', 1],
#  ['Napoli', 'Bologna', 45],
#  ['Napoli', 'Brescia', 1],
#  ['Napoli', 'Ferrara', 7],
#  ['Napoli', 'Firenze', 40],
#  ['Napoli', 'Milano', 45],
#  ['Napoli', 'Padova', 10],
#  ['Napoli', "Reggio nell'Emilia", 23],
#  ['Napoli', 'Roma', 56],
#  ['Napoli', 'Rovigo', 4],
#  ['Napoli', 'Salerno', 13],
#  ['Napoli', 'Torino', 20],
#  ['Napoli', 'Treviso', 2],
#  ['Napoli', 'Udine', 2],
#  ['Napoli', 'Venezia', 10],
#  ['Padova', 'Bologna', 18],
#  ['Padova', 'Brescia', 25],
#  ['Padova', 'Ferrara', 13],
#  ['Padova', 'Firenze', 16],
#  ['Padova', 'Genova', 1],
#  ['Padova', 'Milano', 25],
#  ['Padova', 'Napoli', 10],
#  ['Padova', 'Pavia', 1],
#  ['Padova', 'Roma', 18],
#  ['Padova', 'Rovigo', 3],
#  ['Padova', 'Salerno', 1],
#  ['Padova', 'Torino', 1],
#  ['Padova', 'Treviso', 3],
#  ['Padova', 'Trieste', 3],
#  ['Padova', 'Udine', 3],
#  ['Padova', 'Venezia', 48],
#  ['Padova', 'Verona', 25],
#  ['Padova', 'Vicenza', 25],
#  ['Parma', 'Bologna', 1],
#  ['Parma', 'Firenze', 1],
#  ['Parma', 'Milano', 1],
#  ['Parma', 'Modena', 1],
#  ['Parma', 'Piacenza', 1],
#  ['Parma', "Reggio nell'Emilia", 1],
#  ['Parma', 'Roma', 1],
#  ['Pavia', 'Brescia', 1],
#  ['Pavia', 'Genova', 1],
#  ['Pavia', 'Milano', 1],
#  ['Pavia', 'Padova', 1],
#  ['Pavia', 'Venezia', 1],
#  ['Pavia', 'Verona', 1],
#  ['Pavia', 'Vicenza', 1],
#  ['Perugia', 'Bologna', 1],
#  ['Perugia', 'Firenze', 1],
#  ['Perugia', 'Milano', 1],
#  ['Perugia', "Reggio nell'Emilia", 1],
#  ['Perugia', 'Torino', 1],
#  ['Pesaro', 'Ancona', 3],
#  ['Pesaro', 'Bari', 3],
#  ['Pesaro', 'Barletta', 3],
#  ['Pesaro', 'Bologna', 4],
#  ['Pesaro', 'Brindisi', 2],
#  ['Pesaro', 'Foggia', 3],
#  ['Pesaro', 'Forlì', 1],
#  ['Pesaro', 'Lecce', 2],
#  ['Pesaro', 'Milano', 4],
#  ['Pesaro', 'Pescara', 3],
#  ['Pesaro', "Reggio nell'Emilia", 4],
#  ['Pesaro', 'Riccione', 2],
#  ['Pesaro', 'Rimini', 4],
#  ['Pesaro', 'Termoli', 3],
#  ['Pesaro', 'Torino', 3],
#  ['Pescara', 'Ancona', 5],
#  ['Pescara', 'Bari', 4],
#  ['Pescara', 'Barletta', 3],
#  ['Pescara', 'Bologna', 5],
#  ['Pescara', 'Brindisi', 2],
#  ['Pescara', 'Foggia', 4],
#  ['Pescara', 'Forlì', 1],
#  ['Pescara', 'Lecce', 2],
#  ['Pescara', 'Milano', 5],
#  ['Pescara', 'Pesaro', 3],
#  ['Pescara', "Reggio nell'Emilia", 5],
#  ['Pescara', 'Riccione', 2],
#  ['Pescara', 'Rimini', 5],
#  ['Pescara', 'Termoli', 4],
#  ['Pescara', 'Torino', 3],
#  ['Piacenza', 'Bologna', 1],
#  ['Piacenza', 'Firenze', 1],
#  ['Piacenza', 'Milano', 1],
#  ['Piacenza', 'Modena', 1],
#  ['Piacenza', 'Parma', 1],
#  ['Piacenza', "Reggio nell'Emilia", 1],
#  ['Piacenza', 'Roma', 1],
#  ["Reggio nell'Emilia", 'Ancona', 5],
#  ["Reggio nell'Emilia", 'Bari', 4],
#  ["Reggio nell'Emilia", 'Barletta', 3],
#  ["Reggio nell'Emilia", 'Bologna', 44],
#  ["Reggio nell'Emilia", 'Brindisi', 2],
#  ["Reggio nell'Emilia", 'Firenze', 34],
#  ["Reggio nell'Emilia", 'Foggia', 4],
#  ["Reggio nell'Emilia", 'Forlì', 1],
#  ["Reggio nell'Emilia", 'Lecce', 2],
#  ["Reggio nell'Emilia", 'Milano', 44],
#  ["Reggio nell'Emilia", 'Modena', 1],
#  ["Reggio nell'Emilia", 'Napoli', 23],
#  ["Reggio nell'Emilia", 'Parma', 1],
#  ["Reggio nell'Emilia", 'Perugia', 1],
#  ["Reggio nell'Emilia", 'Pesaro', 4],
#  ["Reggio nell'Emilia", 'Pescara', 5],
#  ["Reggio nell'Emilia", 'Piacenza', 1],
#  ["Reggio nell'Emilia", 'Riccione', 2],
#  ["Reggio nell'Emilia", 'Rimini', 5],
#  ["Reggio nell'Emilia", 'Roma', 31],
#  ["Reggio nell'Emilia", 'Salerno', 8],
#  ["Reggio nell'Emilia", 'Termoli', 4],
#  ["Reggio nell'Emilia", 'Torino', 4],
#  ['Riccione', 'Ancona', 2],
#  ['Riccione', 'Bari', 2],
#  ['Riccione', 'Barletta', 2],
#  ['Riccione', 'Bologna', 2],
#  ['Riccione', 'Brindisi', 2],
#  ['Riccione', 'Foggia', 2],
#  ['Riccione', 'Lecce', 2],
#  ['Riccione', 'Milano', 2],
#  ['Riccione', 'Pesaro', 2],
#  ['Riccione', 'Pescara', 2],
#  ['Riccione', "Reggio nell'Emilia", 2],
#  ['Riccione', 'Rimini', 2],
#  ['Riccione', 'Termoli', 2],
#  ['Riccione', 'Torino', 2],
#  ['Rimini', 'Ancona', 5],
#  ['Rimini', 'Bari', 4],
#  ['Rimini', 'Barletta', 3],
#  ['Rimini', 'Bologna', 5],
#  ['Rimini', 'Brindisi', 3],
#  ['Rimini', 'Foggia', 4],
#  ['Rimini', 'Forlì', 1],
#  ['Rimini', 'Lecce', 3],
#  ['Rimini', 'Milano', 5],
#  ['Rimini', 'Pesaro', 4],
#  ['Rimini', 'Pescara', 5],
#  ['Rimini', "Reggio nell'Emilia", 5],
#  ['Rimini', 'Riccione', 2],
#  ['Rimini', 'Termoli', 4],
#  ['Rimini', 'Torino', 3],
#  ['Roma', 'Bergamo', 1],
#  ['Roma', 'Bologna', 67],
#  ['Roma', 'Bolzano', 1],
#  ['Roma', 'Brescia', 2],
#  ['Roma', 'Ferrara', 12],
#  ['Roma', 'Firenze', 51],
#  ['Roma', 'Milano', 65],
#  ['Roma', 'Modena', 1],
#  ['Roma', 'Napoli', 56],
#  ['Roma', 'Padova', 18],
#  ['Roma', 'Parma', 1],
#  ['Roma', 'Piacenza', 1],
#  ['Roma', "Reggio nell'Emilia", 31],
#  ['Roma', 'Rovigo', 4],
#  ['Roma', 'Salerno', 13],
#  ['Roma', 'Torino', 26],
#  ['Roma', 'Trento', 1],
#  ['Roma', 'Treviso', 2],
#  ['Roma', 'Udine', 2],
#  ['Roma', 'Venezia', 18],
#  ['Roma', 'Verona', 2],
#  ['Rovigo', 'Bologna', 4],
#  ['Rovigo', 'Firenze', 4],
#  ['Rovigo', 'Napoli', 4],
#  ['Rovigo', 'Padova', 3],
#  ['Rovigo', 'Roma', 4],
#  ['Rovigo', 'Venezia', 3],
#  ['Salerno', 'Bologna', 11],
#  ['Salerno', 'Ferrara', 1],
#  ['Salerno', 'Firenze', 11],
#  ['Salerno', 'Milano', 12],
#  ['Salerno', 'Napoli', 13],
#  ['Salerno', 'Padova', 1],
#  ['Salerno', "Reggio nell'Emilia", 8],
#  ['Salerno', 'Roma', 13],
#  ['Salerno', 'Torino', 3],
#  ['Salerno', 'Venezia', 1],
#  ['Termoli', 'Ancona', 4],
#  ['Termoli', 'Bari', 4],
#  ['Termoli', 'Barletta', 3],
#  ['Termoli', 'Bologna', 4],
#  ['Termoli', 'Brindisi', 2],
#  ['Termoli', 'Foggia', 4],
#  ['Termoli', 'Lecce', 2],
#  ['Termoli', 'Milano', 4],
#  ['Termoli', 'Pesaro', 3],
#  ['Termoli', 'Pescara', 4],
#  ['Termoli', "Reggio nell'Emilia", 4],
#  ['Termoli', 'Riccione', 2],
#  ['Termoli', 'Rimini', 4],
#  ['Termoli', 'Torino', 3],
#  ['Torino', 'Ancona', 3],
#  ['Torino', 'Bari', 3],
#  ['Torino', 'Barletta', 3],
#  ['Torino', 'Bologna', 18],
#  ['Torino', 'Brescia', 2],
#  ['Torino', 'Brindisi', 2],
#  ['Torino', 'Firenze', 12],
#  ['Torino', 'Foggia', 3],
#  ['Torino', 'Lecce', 2],
#  ['Torino', 'Milano', 80],
#  ['Torino', 'Napoli', 20],
#  ['Torino', 'Padova', 1],
#  ['Torino', 'Perugia', 1],
#  ['Torino', 'Pesaro', 3],
#  ['Torino', 'Pescara', 3],
#  ['Torino', "Reggio nell'Emilia", 4],
#  ['Torino', 'Riccione', 2],
#  ['Torino', 'Rimini', 3],
#  ['Torino', 'Roma', 26],
#  ['Torino', 'Salerno', 3],
#  ['Torino', 'Termoli', 3],
#  ['Torino', 'Trieste', 1],
#  ['Torino', 'Venezia', 3],
#  ['Torino', 'Verona', 2],
#  ['Torino', 'Vicenza', 1],
#  ['Trento', 'Bologna', 1],
#  ['Trento', 'Bolzano', 2],
#  ['Trento', 'Brescia', 1],
#  ['Trento', 'Firenze', 1],
#  ['Trento', 'Milano', 1],
#  ['Trento', 'Roma', 1],
#  ['Trento', 'Verona', 2],
#  ['Treviso', 'Bologna', 2],
#  ['Treviso', 'Brescia', 1],
#  ['Treviso', 'Ferrara', 2],
#  ['Treviso', 'Firenze', 2],
#  ['Treviso', 'Milano', 1],
#  ['Treviso', 'Napoli', 2],
#  ['Treviso', 'Padova', 3],
#  ['Treviso', 'Roma', 2],
#  ['Treviso', 'Udine', 2],
#  ['Treviso', 'Venezia', 3],
#  ['Treviso', 'Verona', 1],
#  ['Treviso', 'Vicenza', 1],
#  ['Trieste', 'Brescia', 4],
#  ['Trieste', 'Milano', 4],
#  ['Trieste', 'Padova', 3],
#  ['Trieste', 'Torino', 1],
#  ['Trieste', 'Venezia', 4],
#  ['Trieste', 'Verona', 4],
#  ['Trieste', 'Vicenza', 3],
#  ['Udine', 'Bologna', 2],
#  ['Udine', 'Brescia', 1],
#  ['Udine', 'Ferrara', 2],
#  ['Udine', 'Firenze', 2],
#  ['Udine', 'Milano', 1],
#  ['Udine', 'Napoli', 2],
#  ['Udine', 'Padova', 3],
#  ['Udine', 'Roma', 2],
#  ['Udine', 'Treviso', 2],
#  ['Udine', 'Venezia', 3],
#  ['Udine', 'Verona', 1],
#  ['Udine', 'Vicenza', 1],
#  ['Venezia', 'Bologna', 18],
#  ['Venezia', 'Brescia', 30],
#  ['Venezia', 'Ferrara', 13],
#  ['Venezia', 'Firenze', 16],
#  ['Venezia', 'Genova', 1],
#  ['Venezia', 'Milano', 25],
#  ['Venezia', 'Napoli', 10],
#  ['Venezia', 'Padova', 48],
#  ['Venezia', 'Pavia', 1],
#  ['Venezia', 'Roma', 18],
#  ['Venezia', 'Rovigo', 3],
#  ['Venezia', 'Salerno', 1],
#  ['Venezia', 'Torino', 3],
#  ['Venezia', 'Treviso', 3],
#  ['Venezia', 'Trieste', 4],
#  ['Venezia', 'Udine', 3],
#  ['Venezia', 'Verona', 30],
#  ['Venezia', 'Vicenza', 30],
#  ['Verona', 'Bergamo', 1],
#  ['Verona', 'Bologna', 2],
#  ['Verona', 'Bolzano', 2],
#  ['Verona', 'Brescia', 32],
#  ['Verona', 'Firenze', 2],
#  ['Verona', 'Genova', 1],
#  ['Verona', 'Milano', 32],
#  ['Verona', 'Padova', 25],
#  ['Verona', 'Pavia', 1],
#  ['Verona', 'Roma', 2],
#  ['Verona', 'Torino', 2],
#  ['Verona', 'Trento', 2],
#  ['Verona', 'Treviso', 1],
#  ['Verona', 'Trieste', 4],
#  ['Verona', 'Udine', 1],
#  ['Verona', 'Venezia', 30],
#  ['Verona', 'Vicenza', 25],
#  ['Vicenza', 'Brescia', 25],
#  ['Vicenza', 'Genova', 1],
#  ['Vicenza', 'Milano', 25],
#  ['Vicenza', 'Padova', 25],
#  ['Vicenza', 'Pavia', 1],
#  ['Vicenza', 'Torino', 1],
#  ['Vicenza', 'Treviso', 1],
#  ['Vicenza', 'Trieste', 3],
#  ['Vicenza', 'Udine', 1],
#  ['Vicenza', 'Venezia', 30],
#  ['Vicenza', 'Verona', 25]]

# %% [markdown]
# ### Controllo che tutte le cittá che abbiamo siano riconosciute nel dataset dei comuni con i codici istat

# %%
# 0 id_istat
# 1 nome comune
# 2 long
# 3 lat
# 4 regione
for riga in quadri_new:
    if not riga[0] in [comune[1] for comune in comuni]:
        print("problema: cittá source non trovata", riga[0])
    if not riga[1] in [comune[1] for comune in comuni]:
        print("problema: cittá dest non trovata", riga[1])

# %% [markdown]
# ### converto nomi città in codici istat

# %%
def converti_in_codici_coord(quadro, comuni):
    quadro_conv = []
    nomi_comuni = [comune[1] for comune in comuni]
    for riga in quadro:
        index_source = nomi_comuni.index(riga[0])
        index_dest = nomi_comuni.index(riga[1])
        quadro_conv.append([comuni[index_source][0],comuni[index_source][2],comuni[index_source][3],
                            comuni[index_dest][0],comuni[index_dest][2],comuni[index_dest][3],riga[2]])
    return quadro_conv

def converti_in_codici(quadro, comuni):
    quadro_conv = []
    nomi_comuni = [comune[1] for comune in comuni]
    for riga in quadro:
        index_source = nomi_comuni.index(riga[0])
        index_dest = nomi_comuni.index(riga[1])
        quadro_conv.append([comuni[index_source][0],comuni[index_dest][0],riga[2]])
    return quadro_conv

quadro_prov_codici_coord = converti_in_codici_coord(quadri_new, comuni)
quadro_prov_codici = converti_in_codici(quadri_new, comuni)
#quadro_prov_codici
#contiene in sequenza: codice istat source, long source, lat source, codice istat dest, long dest, lat dest, numero treni

# %%
len(quadro_prov_codici_coord)
# Out:
# 536

# %% [markdown]
# Normalizzo al numero di treni totali, per ottenere una visualizzazione completa del grado degli spostamenti tramite ferrovie AV in Italia.

# %%
quadri_prov_prob=[]
i=0
for value in quadro_prov_codici_coord:
    i+=value[6]
i
for value in quadro_prov_codici_coord:
    quadri_prov_prob.append([value[0],value[1],value[2],value[3],value[4],value[5],value[6]/i])
#quadri_prov_prob

#contiene in sequenza: codice istat source, long source, lat source, codice istat dest, long dest, lat dest, probabilità

# %%
import folium

def create_map(center=[42,13]):
    return folium.Map(location=center, zoom_start=5)

def add_prov(mappa, prov):
    a = folium.Circle(radius=5e3, location=[float(prov[2]), float(prov[1])],
                         ).add_to(mappa)
    return a

def add_link(mappa, prov):
    b = folium.PolyLine(locations=[[float(prov[2]), float(prov[1])],[float(prov[5]), float(prov[4])]],
                        weight=prov[6]*10**2, color='black').add_to(mappa)
    
    
m = create_map()
for prov in quadri_prov_prob:
    add_prov(m, prov)
    add_link(m, prov)
m.save('mappa_italia_treni.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Chiara
# # Adesso considero di nuovo la lista "quadro_prov_codici_coord". Ciò che vogliamo fare è normalizzare relativamente al numero di treni della singola città, non a quelli di tutta Italia.

# %%
#cerco come prima cosa il fattore di normalizzazione dei treni per singola privincia
sing_norm=[]
treni=0
c=0
for ii,riga in enumerate(quadro_prov_codici_coord):
    treni+=float(riga[6]) # all'inizio sto sull'ii di riferimento
    c+=1
    if riga[0] != quadro_prov_codici_coord[ii-1][0]:
        if ii !=0:
            treni -= float(riga[6])
            #print(ii)
            for i in range(1,c):
                sing_norm.append(treni)
            c=1
            treni=float(riga[6])
    if ii==535:
        for i in range(0,c):
            sing_norm.append(treni)

# %%
len(sing_norm)
# Out:
# 536

# %%
for i in range(0,536):
    print(quadro_prov_codici_coord[i][0],quadro_prov_codici_coord[i][6],sing_norm[i])

# %%
quadro_prov_sing_norm=[] #contiene le tratte normalizzate in base al numero di treni della singola provincia
for jj,value in enumerate(quadro_prov_codici_coord):
    quadro_prov_sing_norm.append([value[0],value[1],value[2],value[3],value[4],value[5],value[6]/sing_norm[jj]])
quadro_prov_sing_norm

# %%
with open('province_norm.csv','w') as f:
    for a in quadro_prov_sing_norm:
        f.write(f'{a[0]},{a[3]},{a[6]}\n')

# %% [markdown]
# ## Sommo sulle regioni prima convertendo i label in regioni, e poi sommando sui doppioni

# %%
def somma_su_doppioni_direzionata(quadri):
    quadri_new = []
    lista_tratte = []
    for riga in quadri:
        if (riga[0]+riga[1] in lista_tratte):
            index = lista_tratte.index(riga[0]+riga[1])
            quadri_new[index][2] += riga[2]
        else:
            quadri_new.append(riga)
            lista_tratte = [rigaa[0]+rigaa[1] for rigaa in quadri_new]
    
    return quadri_new


quadri_regioni = []
lista_comuni = [comune[1] for comune in comuni]
for riga in quadri_new:
    index_source = lista_comuni.index(riga[0])
    index_dest = lista_comuni.index(riga[1])
    quadri_regioni.append([comuni[index_source][4],comuni[index_dest][4],riga[2]])

# cerco treni che viaggiano all'interno della stessa regione
indici_da_eliminare = []
for ii, riga in enumerate(quadri_regioni):
    if riga[0]==riga[1]:
        indici_da_eliminare.append(ii)

for indice in indici_da_eliminare[::-1]: # vado all'indietro altrimenti gli indici si modificano
    quadri_regioni.pop(indice)
quadri_regioni = somma_su_doppioni_direzionata(quadri_regioni)

quadri_regioni = sorted(sorted(quadri_regioni,key=lambda x: x[1]), key=lambda x: x[0])

# %%
quadri_regioni
# Out:
# [['Abruzzo', 'Emilia-Romagna', 18],
#  ['Abruzzo', 'Lombardia', 5],
#  ['Abruzzo', 'Marche', 8],
#  ['Abruzzo', 'Molise', 4],
#  ['Abruzzo', 'Piemonte', 3],
#  ['Abruzzo', 'Puglia', 15],
#  ['Campania', 'Emilia-Romagna', 95],
#  ['Campania', 'Friuli-Venezia Giulia', 2],
#  ['Campania', 'Lazio', 69],
#  ['Campania', 'Lombardia', 58],
#  ['Campania', 'Piemonte', 23],
#  ['Campania', 'Toscana', 51],
#  ['Campania', 'Veneto', 28],
#  ['Emilia-Romagna', 'Abruzzo', 18],
#  ['Emilia-Romagna', 'Campania', 95],
#  ['Emilia-Romagna', 'Friuli-Venezia Giulia', 4],
#  ['Emilia-Romagna', 'Lazio', 113],
#  ['Emilia-Romagna', 'Lombardia', 118],
#  ['Emilia-Romagna', 'Marche', 33],
#  ['Emilia-Romagna', 'Molise', 14],
#  ['Emilia-Romagna', 'Piemonte', 27],
#  ['Emilia-Romagna', 'Puglia', 57],
#  ['Emilia-Romagna', 'Toscana', 100],
#  ['Emilia-Romagna', 'Trentino-Alto Adige', 2],
#  ['Emilia-Romagna', 'Umbria', 2],
#  ['Emilia-Romagna', 'Veneto', 72],
#  ['Friuli-Venezia Giulia', 'Campania', 2],
#  ['Friuli-Venezia Giulia', 'Emilia-Romagna', 4],
#  ['Friuli-Venezia Giulia', 'Lazio', 2],
#  ['Friuli-Venezia Giulia', 'Lombardia', 10],
#  ['Friuli-Venezia Giulia', 'Piemonte', 1],
#  ['Friuli-Venezia Giulia', 'Toscana', 2],
#  ['Friuli-Venezia Giulia', 'Veneto', 24],
#  ['Lazio', 'Campania', 69],
#  ['Lazio', 'Emilia-Romagna', 113],
#  ['Lazio', 'Friuli-Venezia Giulia', 2],
#  ['Lazio', 'Lombardia', 68],
#  ['Lazio', 'Piemonte', 26],
#  ['Lazio', 'Toscana', 51],
#  ['Lazio', 'Trentino-Alto Adige', 2],
#  ['Lazio', 'Veneto', 44],
#  ['Liguria', 'Lombardia', 3],
#  ['Liguria', 'Veneto', 4],
#  ['Lombardia', 'Abruzzo', 5],
#  ['Lombardia', 'Campania', 58],
#  ['Lombardia', 'Emilia-Romagna', 118],
#  ['Lombardia', 'Friuli-Venezia Giulia', 10],
#  ['Lombardia', 'Lazio', 68],
#  ['Lombardia', 'Liguria', 3],
#  ['Lombardia', 'Marche', 9],
#  ['Lombardia', 'Molise', 4],
#  ['Lombardia', 'Piemonte', 82],
#  ['Lombardia', 'Puglia', 15],
#  ['Lombardia', 'Toscana', 36],
#  ['Lombardia', 'Trentino-Alto Adige', 4],
#  ['Lombardia', 'Umbria', 1],
#  ['Lombardia', 'Veneto', 226],
#  ['Marche', 'Abruzzo', 8],
#  ['Marche', 'Emilia-Romagna', 33],
#  ['Marche', 'Lombardia', 9],
#  ['Marche', 'Molise', 7],
#  ['Marche', 'Piemonte', 6],
#  ['Marche', 'Puglia', 28],
#  ['Molise', 'Abruzzo', 4],
#  ['Molise', 'Emilia-Romagna', 14],
#  ['Molise', 'Lombardia', 4],
#  ['Molise', 'Marche', 7],
#  ['Molise', 'Piemonte', 3],
#  ['Molise', 'Puglia', 15],
#  ['Piemonte', 'Abruzzo', 3],
#  ['Piemonte', 'Campania', 23],
#  ['Piemonte', 'Emilia-Romagna', 27],
#  ['Piemonte', 'Friuli-Venezia Giulia', 1],
#  ['Piemonte', 'Lazio', 26],
#  ['Piemonte', 'Lombardia', 82],
#  ['Piemonte', 'Marche', 6],
#  ['Piemonte', 'Molise', 3],
#  ['Piemonte', 'Puglia', 13],
#  ['Piemonte', 'Toscana', 12],
#  ['Piemonte', 'Umbria', 1],
#  ['Piemonte', 'Veneto', 7],
#  ['Puglia', 'Abruzzo', 15],
#  ['Puglia', 'Emilia-Romagna', 57],
#  ['Puglia', 'Lombardia', 15],
#  ['Puglia', 'Marche', 28],
#  ['Puglia', 'Molise', 15],
#  ['Puglia', 'Piemonte', 13],
#  ['Toscana', 'Campania', 51],
#  ['Toscana', 'Emilia-Romagna', 100],
#  ['Toscana', 'Friuli-Venezia Giulia', 2],
#  ['Toscana', 'Lazio', 51],
#  ['Toscana', 'Lombardia', 36],
#  ['Toscana', 'Piemonte', 12],
#  ['Toscana', 'Trentino-Alto Adige', 2],
#  ['Toscana', 'Umbria', 1],
#  ['Toscana', 'Veneto', 40],
#  ['Trentino-Alto Adige', 'Emilia-Romagna', 2],
#  ['Trentino-Alto Adige', 'Lazio', 2],
#  ['Trentino-Alto Adige', 'Lombardia', 4],
#  ['Trentino-Alto Adige', 'Toscana', 2],
#  ['Trentino-Alto Adige', 'Veneto', 4],
#  ['Umbria', 'Emilia-Romagna', 2],
#  ['Umbria', 'Lombardia', 1],
#  ['Umbria', 'Piemonte', 1],
#  ['Umbria', 'Toscana', 1],
#  ['Veneto', 'Campania', 28],
#  ['Veneto', 'Emilia-Romagna', 72],
#  ['Veneto', 'Friuli-Venezia Giulia', 24],
#  ['Veneto', 'Lazio', 44],
#  ['Veneto', 'Liguria', 4],
#  ['Veneto', 'Lombardia', 226],
#  ['Veneto', 'Piemonte', 7],
#  ['Veneto', 'Toscana', 40],
#  ['Veneto', 'Trentino-Alto Adige', 4]]

# %% [markdown]
# # lombardia veneto 226 treni: molti di più delle altre regioni. Strano ?

# %% [markdown]
# # Ora bisogna associare ad ogni regione il suo capoluogo
